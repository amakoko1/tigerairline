# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from bs4 import BeautifulSoup
import re
driver = webdriver.Chrome()
cookie_1={'_ga': 'GA1.2.1865830651.1542781284',
 '_gat': '1',
 '_gat_UA-86813519-1': '1',
 '_gid': 'GA1.2.1086759663.1548728590',
 'ins-gaSSId': 'ad25155b-03fa-629d-7f44-0f96c16f7c8c_1548731076',
 'ins-user-behaviour': '%7B%22flightType%22%3A%22Oneway%22%2C%22adultsNumber%22%3A1%2C%22childrenNumber%22%3A0%2C%22infantsNumber%22%3A0%2C%22origin%22%3A%22%E5%8F%B0%E5%8C%97(%E6%A1%83%E5%9C%92)%20(TPE)%22%2C%22destination%22%3A%22%E6%9D%B1%E4%BA%AC%E6%88%90%E7%94%B0%20(NRT)%22%2C%22passengersNumber%22%3A1%2C%22originCountry%22%3A%22%E5%8F%B0%E7%81%A3%22%2C%22destinationCountry%22%3A%22%E6%97%A5%E6%9C%AC%22%2C%22departureDate%22%3A%222019-01-09%22%2C%22arrivalDate%22%3A%222019-01-09%22%2C%22url%22%3A%22https%3A%2F%2Fbooking.tigerairtw.com%2F%3FdlType%3Dfltsrch%26culture%3Dzh-TW%26ms%3DOneway%26psgr%3D1_0_0%26depDate%3D2019-01-09%26retDate%3D2019-01-09%26origin%3DTPE%26dest%3DNRT%26pc%3D%26extraDays%3D3%22%2C%22currency%22%3A%22TWD%22%2C%22originCode%22%3A%22TPE%22%2C%22destinationCode%22%3A%22NRT%22%2C%22lang%22%3A%22zh_tw%22%2C%22lastSearchFlightUrl%22%3A%22https%3A%2F%2Fbooking.tigerairtw.com%2F%3FdlType%3Dfltsrch%26culture%3Dzh-TW%26ms%3DOneway%26psgr%3D1_0_0%26depDate%3D2019-01-09%26retDate%3D2019-01-10%26origin%3DTPE%26dest%3DNRT%26pc%3D%26extraDays%3D3%22%2C%22isBaggageSelected%22%3Afalse%2C%22isMealSelected%22%3Afalse%2C%22isSeatSelected%22%3Afalse%2C%22isInsuranceSelected%22%3Afalse%2C%22promoCode%22%3Afalse%7D',
 'ins-user-logged-in': 'false',
 'insdrSV': '11',
 'scs': '%7B%22t%22%3A1%7D'}
driver.maximize_window()
driver.get("https://www.tigerairtw.com/zh-tw/")
driver.implicitly_wait(10)
driver.add_cookie(cookie_2)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-43-9d72f4f8ba37> in <module>
#      17 driver.get("https://www.tigerairtw.com/zh-tw/")
#      18 driver.implicitly_wait(10)
# ---> 19 driver.add_cookie(cookie_2)
#
# c:\python\lib\site-packages\selenium\webdriver\remote\webdriver.py in add_cookie(self, cookie_dict)
#     747
#     748         """
# --> 749         self.execute(Command.ADD_COOKIE, {'cookie': cookie_dict})
#     750
#     751     # Timeouts
#
# c:\python\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     295         response = self.command_executor.execute(driver_command, params)
#     296         if response:
# --> 297             self.error_handler.check_response(response)
#     298             response['value'] = self._unwrap_value(
#     299                 response.get('value', None))
#
# c:\python\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     192         elif exception_class == UnexpectedAlertPresentException and 'alert' in value:
#     193             raise exception_class(message, screen, stacktrace, value['alert'].get('text'))
# --> 194         raise exception_class(message, screen, stacktrace)
#     195
#     196     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: invalid argument: missing 'name'
#   (Session info: chrome=71.0.3578.98)
#   (Driver info: chromedriver=2.44.609538 (b655c5a60b0b544917107a59d4153d4bf78e1b90),platform=Windows NT 6.1.7601 SP1 x86)

# %%
cookie_1={'_ga': 'GA1.2.1865830651.1542781284',
 '_gat': '1',
 '_gat_UA-86813519-1': '1',
 '_gid': 'GA1.2.1086759663.1548728590',
 'ins-gaSSId': 'ad25155b-03fa-629d-7f44-0f96c16f7c8c_1548731076',
 'ins-user-behaviour': '%7B%22flightType%22%3A%22Oneway%22%2C%22adultsNumber%22%3A1%2C%22childrenNumber%22%3A0%2C%22infantsNumber%22%3A0%2C%22origin%22%3A%22%E5%8F%B0%E5%8C%97(%E6%A1%83%E5%9C%92)%20(TPE)%22%2C%22destination%22%3A%22%E6%9D%B1%E4%BA%AC%E6%88%90%E7%94%B0%20(NRT)%22%2C%22passengersNumber%22%3A1%2C%22originCountry%22%3A%22%E5%8F%B0%E7%81%A3%22%2C%22destinationCountry%22%3A%22%E6%97%A5%E6%9C%AC%22%2C%22departureDate%22%3A%222019-01-09%22%2C%22arrivalDate%22%3A%222019-01-09%22%2C%22url%22%3A%22https%3A%2F%2Fbooking.tigerairtw.com%2F%3FdlType%3Dfltsrch%26culture%3Dzh-TW%26ms%3DOneway%26psgr%3D1_0_0%26depDate%3D2019-01-09%26retDate%3D2019-01-09%26origin%3DTPE%26dest%3DNRT%26pc%3D%26extraDays%3D3%22%2C%22currency%22%3A%22TWD%22%2C%22originCode%22%3A%22TPE%22%2C%22destinationCode%22%3A%22NRT%22%2C%22lang%22%3A%22zh_tw%22%2C%22lastSearchFlightUrl%22%3A%22https%3A%2F%2Fbooking.tigerairtw.com%2F%3FdlType%3Dfltsrch%26culture%3Dzh-TW%26ms%3DOneway%26psgr%3D1_0_0%26depDate%3D2019-01-09%26retDate%3D2019-01-10%26origin%3DTPE%26dest%3DNRT%26pc%3D%26extraDays%3D3%22%2C%22isBaggageSelected%22%3Afalse%2C%22isMealSelected%22%3Afalse%2C%22isSeatSelected%22%3Afalse%2C%22isInsuranceSelected%22%3Afalse%2C%22promoCode%22%3Afalse%7D',
 'ins-user-logged-in': 'false',
 'insdrSV': '11',
 'scs': '%7B%22t%22%3A1%7D'}

# %%
cookie_2={'_ga': 'GA1.2.1865830651.1542781284', '_gat': '1', '_gat_UA-86813519-1': '1', '_gid': 'GA1.2.1086759663.1548728590', 'ins-gaSSId': 'ad25155b-03fa-629d-7f44-0f96c16f7c8c_1548731076', 'ins-user-behaviour': '%7B%22flightType%22%3A%22Oneway%22%2C%22adultsNumber%22%3A1%2C%22childrenNumber%22%3A0%2C%22infantsNumber%22%3A0%2C%22origin%22%3A%22%E5%8F%B0%E5%8C%97(%E6%A1%83%E5%9C%92)%20(TPE)%22%2C%22destination%22%3A%22%E6%9D%B1%E4%BA%AC%E6%88%90%E7%94%B0%20(NRT)%22%2C%22passengersNumber%22%3A1%2C%22originCountry%22%3A%22%E5%8F%B0%E7%81%A3%22%2C%22destinationCountry%22%3A%22%E6%97%A5%E6%9C%AC%22%2C%22departureDate%22%3A%222019-01-09%22%2C%22arrivalDate%22%3A%222019-01-09%22%2C%22url%22%3A%22https%3A%2F%2Fbooking.tigerairtw.com%2F%3FdlType%3Dfltsrch%26culture%3Dzh-TW%26ms%3DOneway%26psgr%3D1_0_0%26depDate%3D2019-01-09%26retDate%3D2019-01-09%26origin%3DTPE%26dest%3DNRT%26pc%3D%26extraDays%3D3%22%2C%22currency%22%3A%22TWD%22%2C%22originCode%22%3A%22TPE%22%2C%22destinationCode%22%3A%22NRT%22%2C%22lang%22%3A%22zh_tw%22%2C%22lastSearchFlightUrl%22%3A%22https%3A%2F%2Fbooking.tigerairtw.com%2F%3FdlType%3Dfltsrch%26culture%3Dzh-TW%26ms%3DOneway%26psgr%3D1_0_0%26depDate%3D2019-01-09%26retDate%3D2019-01-10%26origin%3DTPE%26dest%3DNRT%26pc%3D%26extraDays%3D3%22%2C%22isBaggageSelected%22%3Afalse%2C%22isMealSelected%22%3Afalse%2C%22isSeatSelected%22%3Afalse%2C%22isInsuranceSelected%22%3Afalse%2C%22promoCode%22%3Afalse%7D', 'ins-user-logged-in': 'false', 'insdrSV': '11', 'scs': '%7B%22t%22%3A1%7D'}

# %%
import requests
url='https://www.tigerairtw.com/zh-tw/'

response=requests.get(url,cookies=cookie_2)

# %%
cookie_list = driver.get_cookies()
print(cookie_list)
# Out:
# [{'domain': '.tigerairtw.com', 'httpOnly': False, 'name': 'ins-user-logged-in', 'path': '/', 'secure': False, 'value': 'false'}, {'domain': '.tigerairtw.com', 'expiry': 1548834854, 'httpOnly': False, 'name': '_gid', 'path': '/', 'secure': False, 'value': 'GA1.2.276964040.1548748451'}, {'domain': '.tigerairtw.com', 'expiry': 1611820454, 'httpOnly': False, 'name': '_ga', 'path': '/', 'secure': False, 'value': 'GA1.2.1243040418.1548748451'}, {'domain': '.tigerairtw.com', 'expiry': 1549958054, 'httpOnly': False, 'name': 'scs', 'path': '/', 'secure': False, 'value': '%7B%22t%22%3A1%7D'}, {'domain': '.tigerairtw.com', 'expiry': 1580284454, 'httpOnly': False, 'name': 'insdrSV', 'path': '/', 'secure': False, 'value': '1'}, {'domain': '.tigerairtw.com', 'expiry': 1548750254, 'httpOnly': False, 'name': 'ins-gaSSId', 'path': '/', 'secure': False, 'value': '3ea34cf5-8e76-c236-9e9e-3112a6fd926f_1548748455'}, {'domain': '.booking.tigerairtw.com', 'expiry': 1548835113, 'httpOnly': False, 'name': '_gid', 'path': '/', 'secure': False, 'value': 'GA1.3.276964040.1548748451'}, {'domain': '.booking.tigerairtw.com', 'expiry': 1611820713, 'httpOnly': False, 'name': '_ga', 'path': '/', 'secure': False, 'value': 'GA1.3.1243040418.1548748451'}, {'domain': '.tigerairtw.com', 'expiry': 1580284713, 'httpOnly': False, 'name': 'ins-user-behaviour', 'path': '/', 'secure': False, 'value': '%7B%22originCountry%22%3A%22%E5%8F%B0%E7%81%A3%22%2C%22destinationCountry%22%3A%22%E6%97%A5%E6%9C%AC%22%2C%22flightType%22%3A%22Oneway%22%2C%22adultsNumber%22%3A1%2C%22childrenNumber%22%3A0%2C%22infantsNumber%22%3A0%2C%22origin%22%3A%22%E5%8F%B0%E7%81%A3%20-%20%E6%89%80%E6%9C%89%E6%A9%9F%E5%A0%B4%22%2C%22destination%22%3A%22%E9%97%9C%E6%9D%B1%E5%9C%B0%E5%8D%80%20-%20%E6%89%80%E6%9C%89%E6%A9%9F%E5%A0%B4%22%2C%22departureDate%22%3A%222019%2F03%2F01%22%2C%22arrivalDate%22%3A%222019%2F03%2F01%22%2C%22passengersNumber%22%3A1%2C%22originCode%22%3A%22XX3%22%2C%22destinationCode%22%3A%22XX7%22%2C%22lang%22%3A%22zh_tw%22%2C%22lastSearchFlightUrl%22%3A%22https%3A%2F%2Fbooking.tigerairtw.com%2F%3FdlType%3Dfltsrch%26culture%3Dzh-TW%26ms%3DOneway%26psgr%3D1_0_0%26depDate%3D2019-03-01%26retDate%3D2019-03-01%26origin%3DXX3%26dest%3DXX7%26pc%3D%26extraDays%3D3%22%2C%22isBaggageSelected%22%3Afalse%2C%22isMealSelected%22%3Afalse%2C%22isSeatSelected%22%3Afalse%2C%22isInsuranceSelected%22%3Afalse%2C%22promoCode%22%3Afalse%7D'}, {'domain': '.booking.tigerairtw.com', 'expiry': 1580284717, 'httpOnly': False, 'name': 'insdrSV', 'path': '/', 'secure': False, 'value': '2'}, {'domain': 'booking.tigerairtw.com', 'expiry': 1579852717, 'httpOnly': False, 'name': 'ins-mig-done', 'path': '/', 'secure': False, 'value': '1'}, {'domain': '.booking.tigerairtw.com', 'expiry': 1548750525, 'httpOnly': False, 'name': 'ins-gaSSId', 'path': '/', 'secure': False, 'value': '3ea34cf5-8e76-c236-9e9e-3112a6fd926f_1548748455'}, {'domain': 'booking.tigerairtw.com', 'expiry': 1580284725, 'httpOnly': False, 'name': 'spUID', 'path': '/', 'secure': False, 'value': '15487484547545d14276439.5051a8ee'}, {'domain': '.booking.tigerairtw.com', 'expiry': 1549958325, 'httpOnly': False, 'name': 'scs', 'path': '/', 'secure': False, 'value': '%7B%22t%22%3A1%7D'}]

# %%
from selenium import webdriver

driver = webdriver.Chrome()
executor_url = driver.command_executor._url
session_id = driver.session_id
print(session_id)
print(executor_url)
driver.get("https://www.tigerairtw.com/zh-tw/")
# Out:
# da08983195b7f8c1a2fadcccf622262a
# http://127.0.0.1:4629

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from bs4 import BeautifulSoup


driver = webdriver.Chrome()
executor_url = driver.command_executor._url
session_id = driver.session_id
print(session_id)
print(executor_url)
driver.get("https://www.tigerairtw.com/zh-tw/")
# Out:
# 802bb787fe43703dff5587b2dfebbda8
# http://127.0.0.1:4018

# %%
{'_ga': 'GA1.2.1865830651.1542781284', '_gat': '1', '_gat_UA-86813519-1': '1', '_gid': 'GA1.2.1086759663.1548728590', 'ins-gaSSId': 'ad25155b-03fa-629d-7f44-0f96c16f7c8c_1548731076', 'ins-user-behaviour': '%7B%22flightType%22%3A%22Oneway%22%2C%22adultsNumber%22%3A1%2C%22childrenNumber%22%3A0%2C%22infantsNumber%22%3A0%2C%22origin%22%3A%22%E5%8F%B0%E5%8C%97(%E6%A1%83%E5%9C%92)%20(TPE)%22%2C%22destination%22%3A%22%E6%9D%B1%E4%BA%AC%E6%88%90%E7%94%B0%20(NRT)%22%2C%22passengersNumber%22%3A1%2C%22originCountry%22%3A%22%E5%8F%B0%E7%81%A3%22%2C%22destinationCountry%22%3A%22%E6%97%A5%E6%9C%AC%22%2C%22departureDate%22%3A%222019-01-09%22%2C%22arrivalDate%22%3A%222019-01-09%22%2C%22url%22%3A%22https%3A%2F%2Fbooking.tigerairtw.com%2F%3FdlType%3Dfltsrch%26culture%3Dzh-TW%26ms%3DOneway%26psgr%3D1_0_0%26depDate%3D2019-01-09%26retDate%3D2019-01-09%26origin%3DTPE%26dest%3DNRT%26pc%3D%26extraDays%3D3%22%2C%22currency%22%3A%22TWD%22%2C%22originCode%22%3A%22TPE%22%2C%22destinationCode%22%3A%22NRT%22%2C%22lang%22%3A%22zh_tw%22%2C%22lastSearchFlightUrl%22%3A%22https%3A%2F%2Fbooking.tigerairtw.com%2F%3FdlType%3Dfltsrch%26culture%3Dzh-TW%26ms%3DOneway%26psgr%3D1_0_0%26depDate%3D2019-01-09%26retDate%3D2019-01-10%26origin%3DTPE%26dest%3DNRT%26pc%3D%26extraDays%3D3%22%2C%22isBaggageSelected%22%3Afalse%2C%22isMealSelected%22%3Afalse%2C%22isSeatSelected%22%3Afalse%2C%22isInsuranceSelected%22%3Afalse%2C%22promoCode%22%3Afalse%7D', 'ins-user-logged-in': 'false', 'insdrSV': '11', 'scs': '%7B%22t%22%3A1%7D'}

# %%
cookie_list = driver.get_cookies()
print(cookie_list)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-30-159fbc3d5d0b> in <module>
# ----> 1 cookie_list = driver.get_cookies()
#       2 print(cookie_list)
#
# c:\python\lib\site-packages\selenium\webdriver\remote\webdriver.py in get_cookies(self)
#     700             driver.get_cookies()
#     701         """
# --> 702         return self.execute(Command.GET_ALL_COOKIES)['value']
#     703
#     704     def get_cookie(self, name):
#
# c:\python\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     295         response = self.command_executor.execute(driver_command, params)
#     296         if response:
# --> 297             self.error_handler.check_response(response)
#     298             response['value'] = self._unwrap_value(
#     299                 response.get('value', None))
#
# c:\python\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     192         elif exception_class == UnexpectedAlertPresentException and 'alert' in value:
#     193             raise exception_class(message, screen, stacktrace, value['alert'].get('text'))
# --> 194         raise exception_class(message, screen, stacktrace)
#     195
#     196     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=71.0.3578.98)
#   (Driver info: chromedriver=2.44.609538 (b655c5a60b0b544917107a59d4153d4bf78e1b90),platform=Windows NT 6.1.7601 SP1 x86)

# %%
driver.close()
driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from bs4 import BeautifulSoup


driver = webdriver.Chrome()
executor_url = driver.command_executor._url
session_id = driver.session_id
print(session_id)
print(executor_url)


#使用requests设置cookie登录
# 要先访问一次这个域名
# 要先访问一次这个域名
driver.get("https://www.tigerairtw.com/zh-tw/")

for item in cookie_1:
    driver.add_cookie({'domain': '.tigerairtw.com',
    #'name': item['name'],
    #'value': item['value'],
    'sameSite': 'no_restriction',
    'storeId': '0',
    'path': '/',
    #'expires': None
})

driver.implicitly_wait(3)
# Out:
# 3b060161624736acf82db3f6728e3e7f
# http://127.0.0.1:4718
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-28-cc7dfe826621> in <module>
#      23     'sameSite': 'no_restriction',
#      24     'storeId': '0',
# ---> 25     'path': '/',
#      26     #'expires': None
#      27 })
#
# c:\python\lib\site-packages\selenium\webdriver\remote\webdriver.py in add_cookie(self, cookie_dict)
#     747
#     748         """
# --> 749         self.execute(Command.ADD_COOKIE, {'cookie': cookie_dict})
#     750
#     751     # Timeouts
#
# c:\python\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     295         response = self.command_executor.execute(driver_command, params)
#     296         if response:
# --> 297             self.error_handler.check_response(response)
#     298             response['value'] = self._unwrap_value(
#     299                 response.get('value', None))
#
# c:\python\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     192         elif exception_class == UnexpectedAlertPresentException and 'alert' in value:
#     193             raise exception_class(message, screen, stacktrace, value['alert'].get('text'))
# --> 194         raise exception_class(message, screen, stacktrace)
#     195
#     196     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: invalid argument: missing 'name'
#   (Session info: chrome=71.0.3578.98)
#   (Driver info: chromedriver=2.44.609538 (b655c5a60b0b544917107a59d4153d4bf78e1b90),platform=Windows NT 6.1.7601 SP1 x86)

# %%
URL = "https://booking.tigerairtw.com/?dlType=fltsrch&culture=zh-TW&ms=Oneway&psgr=1_0_0&depDate=2019-03-01&retDate=2019-03-04&origin=TPE&dest=AKJ&pc=&extraDays=3"
driver.get(URL)
input('是否有效')
driver.close()
# Out:
# 是否有效是
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-34-9642c8ea73f2> in <module>
#       3 driver.get(URL)
#       4 input('是否有效')
# ----> 5 driver.close()
#
# c:\python\lib\site-packages\selenium\webdriver\remote\webdriver.py in close(self)
#     580             driver.close()
#     581         """
# --> 582         self.execute(Command.CLOSE)
#     583
#     584     def quit(self):
#
# c:\python\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     295         response = self.command_executor.execute(driver_command, params)
#     296         if response:
# --> 297             self.error_handler.check_response(response)
#     298             response['value'] = self._unwrap_value(
#     299                 response.get('value', None))
#
# c:\python\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     192         elif exception_class == UnexpectedAlertPresentException and 'alert' in value:
#     193             raise exception_class(message, screen, stacktrace, value['alert'].get('text'))
# --> 194         raise exception_class(message, screen, stacktrace)
#     195
#     196     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=71.0.3578.98)
#   (Driver info: chromedriver=2.44.609538 (b655c5a60b0b544917107a59d4153d4bf78e1b90),platform=Windows NT 6.1.7601 SP1 x86)

# %%
driver = webdriver.Chrome(executable_path='chromedriver.exe', chrome_options=options)
URL = "https://booking.tigerairtw.com/?dlType=fltsrch&culture=zh-TW&ms=Oneway&psgr=1_0_0&depDate=2019-03-01&retDate=2019-03-04&origin=TPE&dest=AKJ&pc=&extraDays=3"
driver.get(URL)
driver.implicitly_wait(3)
#print(driver.get_cookies())

# %%
cookie_list = driver.get_cookies()
print(cookie_list)
driver.close()
driver.quit()
# Out:
# [{'domain': 'booking.tigerairtw.com', 'expiry': 1579154392, 'httpOnly': False, 'name': 'ins-mig-done', 'path': '/', 'secure': False, 'value': '1'}, {'domain': '.booking.tigerairtw.com', 'expiry': 1548136787, 'httpOnly': False, 'name': '_gid', 'path': '/', 'secure': False, 'value': 'GA1.3.583398317.1548050388'}, {'domain': '.booking.tigerairtw.com', 'expiry': 1611122387, 'httpOnly': False, 'name': '_ga', 'path': '/', 'secure': False, 'value': 'GA1.3.208272208.1548050388'}, {'domain': '.booking.tigerairtw.com', 'expiry': 1548050447, 'httpOnly': False, 'name': '_gat_UA-86813519-1', 'path': '/', 'secure': False, 'value': '1'}, {'domain': '.booking.tigerairtw.com', 'expiry': 1579586392, 'httpOnly': False, 'name': 'insdrSV', 'path': '/', 'secure': False, 'value': '1'}]

# %%
#增加cookie項目
for item in cookie_list: driver.add_cookie({
    'domain': '.tigerairtw.com',
    #'name': item['name'],
    #'value': item['value'],
    'sameSite': 'no_restriction',
    'storeId': '0',
    'path': '/',
    'expires': None
})
# Out:
# ---------------------------------------------------------------------------
# ConnectionAbortedError                    Traceback (most recent call last)
# <ipython-input-13-345e9c9ec003> in <module>
#       7     'storeId': '0',
#       8     'path': '/',
# ----> 9     'expires': None
#      10 })
#
# c:\python\lib\site-packages\selenium\webdriver\remote\webdriver.py in add_cookie(self, cookie_dict)
#     747
#     748         """
# --> 749         self.execute(Command.ADD_COOKIE, {'cookie': cookie_dict})
#     750
#     751     # Timeouts
#
# c:\python\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     293
#     294         params = self._wrap_value(params)
# --> 295         response = self.command_executor.execute(driver_command, params)
#     296         if response:
#     297             self.error_handler.check_response(response)
#
# c:\python\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     462         path = string.Template(command_info[1]).substitute(params)
#     463         url = '%s%s' % (self._url, path)
# --> 464         return self._request(command_info[0], url, body=data)
#     465
#     466     def _request(self, method, url, body=None):
#
# c:\python\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     485                 body = None
#     486             try:
# --> 487                 self._conn.request(method, parsed_url.path, body, headers)
#     488                 resp = self._conn.getresponse()
#     489             except (httplib.HTTPException, socket.error):
#
# c:\python\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1227                 encode_chunked=False):
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#    1231     def _send_request(self, method, url, body, headers, encode_chunked):
#
# c:\python\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1273             # default charset of iso-8859-1.
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#    1277     def getresponse(self):
#
# c:\python\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1222         else:
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#    1226     def request(self, method, url, body=None, headers={}, *,
#
# c:\python\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1053                     chunk = f'{len(chunk):X}\r\n'.encode('ascii') + chunk \
#    1054                         + b'\r\n'
# -> 1055                 self.send(chunk)
#    1056
#    1057             if encode_chunked and self._http_vsn == 11:
#
# c:\python\lib\http\client.py in send(self, data)
#     975             return
#     976         try:
# --> 977             self.sock.sendall(data)
#     978         except TypeError:
#     979             if isinstance(data, collections.abc.Iterable):
#
# ConnectionAbortedError: [WinError 10053] 連線已被您主機上的軟體中止。

# %%
#使用requests设置cookie登录
import requests
cookies = ";".join([item["name"] + "=" + item["value"] + "" for item in cookie_list])
print(cookies)
session = requests.Session()
# cookie要放到headers里
headers = {
    'Cookie': cookies
}
html = session.get(url='https://aso100.com/account/setting/type/dataCenter', headers=headers).content.decode()
print(html)

# %%
from selenium import webdriver

driver = webdriver.Chrome()
executor_url = driver.command_executor._url
session_id = driver.session_id
driver.get("https://www.tigerairtw.com/zh-tw/")

print(session_id)
print(executor_url)

driver2 = webdriver.Remote(command_executor=executor_url, desired_capabilities={})
driver2.session_id = session_id
print(driver2.current_url)
# Out:
# 29fb1ff449bca27fe1fbc55a247b36c0
# http://127.0.0.1:9021
# https://www.tigerairtw.com/zh-tw/

# %%
from selenium import webdriver

#  第一次使用Chrome() 新建浏览器会话
driver = webdriver.Chrome()

# 记录 executor_url 和 session_id 以便复用session
executor_url = driver.command_executor._url
session_id = driver.session_id
# 访问百度
driver.get("https://www.tigerairtw.com/zh-tw/")

print(session_id)
print(executor_url)

# 假如driver对象不存在，但浏览器未关闭
del driver

# 使用ReuseChrome()复用上次的session
driver2 = ReuseChrome(command_executor=executor_url, session_id=session_id)

# 打印current_url为百度的地址，说明复用成功
print(driver2.current_url)
driver2.get("https://www.tigerairtw.com/zh-tw/")
# Out:
# f54c348372ecf1db27d6c9f37e413728
# http://127.0.0.1:6482
# https://www.tigerairtw.com/zh-tw/

# %%
from selenium.webdriver import Remote
from selenium.webdriver.chrome import options
from selenium.common.exceptions import InvalidArgumentException

class ReuseChrome(Remote):

    def __init__(self, command_executor, session_id):
        self.r_session_id = session_id
        Remote.__init__(self, command_executor=command_executor, desired_capabilities={})

    def start_session(self, capabilities, browser_profile=None):
        """
        重写start_session方法
        """
        if not isinstance(capabilities, dict):
            raise InvalidArgumentException("Capabilities must be a dictionary")
        if browser_profile:
            if "moz:firefoxOptions" in capabilities:
                capabilities["moz:chromefoxOptions"]["profile"] = browser_profile.encoded
            else:
                capabilities.update({'chrome_profile': browser_profile.encoded})

        self.capabilities = options.Options().to_capabilities()
        self.session_id = self.r_session_id
        self.w3c = False

# %%
from selenium import webdriver

#  第一次使用Chrome() 新建浏览器会话
driver = webdriver.Chrome()

# 记录 executor_url 和 session_id 以便复用session
executor_url = driver.command_executor._url
session_id = driver.session_id
# 访问百度
driver.get("https://www.tigerairtw.com/zh-tw/")

print(session_id)
print(executor_url)

# 假如driver对象不存在，但浏览器未关闭
del driver

# 使用ReuseChrome()复用上次的session
driver2 = ReuseChrome(command_executor=executor_url, session_id=session_id)

# 打印current_url为百度的地址，说明复用成功
print(driver2.current_url)
driver2.get("https://www.tigerairtw.com/zh-tw/")

# %%
cookie_dict = {
    thing: "thing"
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-6309885434fe> in <module>
#       1 cookie_dict = {
# ----> 2     thing: "thing"
#       3 }
#
# NameError: name 'thing' is not defined

# %%
import requests
from bs4 import BeautifulSoup

headers={
'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36',
'Referer':'https://www.tigerairtw.com/zh-tw/',
'Cookie':'_joomair=TW~TWD~TW; _ga=GA1.2.1865830651.1542781284; ins-mig-done=1; spUID=154278128954746b03b88a1.87a6ddb9; scs=%7B%22t%22%3A1%7D; ins-user-behaviour=%7B%22flightType%22%3A%22Oneway%22%2C%22adultsNumber%22%3A1%2C%22childrenNumber%22%3A0%2C%22infantsNumber%22%3A0%2C%22origin%22%3A%22%E5%8F%B0%E5%8C%97(%E6%A1%83%E5%9C%92)%20(TPE)%22%2C%22destination%22%3A%22%E6%9D%B1%E4%BA%AC%E6%88%90%E7%94%B0%20(NRT)%22%2C%22passengersNumber%22%3A1%2C%22originCountry%22%3A%22%E5%8F%B0%E7%81%A3%22%2C%22destinationCountry%22%3A%22%E6%97%A5%E6%9C%AC%22%2C%22departureDate%22%3A%222019-01-09%22%2C%22arrivalDate%22%3A%222019-01-09%22%2C%22url%22%3A%22https%3A%2F%2Fbooking.tigerairtw.com%2F%3FdlType%3Dfltsrch%26culture%3Dzh-TW%26ms%3DOneway%26psgr%3D1_0_0%26depDate%3D2019-01-09%26retDate%3D2019-01-09%26origin%3DTPE%26dest%3DNRT%26pc%3D%26extraDays%3D3%22%2C%22currency%22%3A%22TWD%22%2C%22originCode%22%3A%22TPE%22%2C%22destinationCode%22%3A%22NRT%22%2C%22lang%22%3A%22zh_tw%22%2C%22lastSearchFlightUrl%22%3A%22https%3A%2F%2Fbooking.tigerairtw.com%2F%3FdlType%3Dfltsrch%26culture%3Dzh-TW%26ms%3DOneway%26psgr%3D1_0_0%26depDate%3D2019-01-09%26retDate%3D2019-01-10%26origin%3DTPE%26dest%3DNRT%26pc%3D%26extraDays%3D3%22%2C%22isBaggageSelected%22%3Afalse%2C%22isMealSelected%22%3Afalse%2C%22isSeatSelected%22%3Afalse%2C%22isInsuranceSelected%22%3Afalse%2C%22promoCode%22%3Afalse%7D; _gid=GA1.2.1485877406.1547694273; _gat=1; _gat_UA-86813519-1=1; ins-user-logged-in=false; insdrSV=8; ins-gaSSId=45833612-b604-9edd-a73c-82caf25b108d_1547694277; _joomair=TW~TWD~TW'
}

# %%
res=requests.get("https://www.tigerairtw.com/zh-tw/",headers=headers)
soup=BeautifulSoup(res.text,'html.parser')
#n=soup.select(".list")[0].select(".item")

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from bs4 import BeautifulSoup


WIDTH = 640
HEIGHT = 640
PIXEL_RATIO = 3.0
#UA = 'Mozilla/5.0 (Linux; Android 4.1.1; GT-N7100 Build/JRO03C) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/35.0.1916.138 Mobile Safari/537.36 T7/6.3'

UA = 'Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2272.96 Mobile Safari/537.36'


mobileEmulation = {"deviceMetrics": {"width": WIDTH, "height": HEIGHT, "pixelRatio": PIXEL_RATIO}, "userAgent": UA}
options = webdriver.ChromeOptions()
options.add_experimental_option('mobileEmulation', mobileEmulation)
#options.add_argument(r'user-data-dir=C:\Users\kidde\AppData\Local\Google\Chrome\User Data')
#options.add_argument('--proxy-server=http://proxy.seed.net.tw:8080')

# %%
driver = webdriver.Chrome(executable_path='chromedriver.exe', chrome_options=options)
URL = "https://booking.tigerairtw.com/?dlType=fltsrch&culture=zh-TW&ms=Oneway&psgr=1_0_0&depDate=2019-03-01&retDate=2019-03-04&origin=TPE&dest=AKJ&pc=&extraDays=3"
driver.get(URL)
driver.implicitly_wait(3)
#print(driver.get_cookies())

# %%
import subprocess
import sqlite3
import win32crypt

import requests

SOUR_COOKIE_FILENAME = r'C:\Users\pi\AppData\Local\Google\Chrome\User Data\Default\Cookies'
DIST_COOKIE_FILENAME = '.\python-chrome-cookies'


def get_chrome_cookies(url):
    subprocess.call(['copy', SOUR_COOKIE_FILENAME, DIST_COOKIE_FILENAME], shell=True)
    conn = sqlite3.connect(".\python-chrome-cookies")
    ret_dict = {}
    for row in conn.execute("SELECT host_key, name, path, value, encrypted_value FROM cookies"):
        # if row[0] not in url:
        if row[0] != url:
            continue
        print(row[0])
        ret = win32crypt.CryptUnprotectData(row[4], None, None, None, 0)
        ret_dict[row[1]] = ret[1].decode()
    conn.close()
    subprocess.call(['del', '.\python-chrome-cookies'], shell=True)
    return ret_dict

# %%
DOMAIN_NAME = '.tigerairtw.com'
get_url = r'https://www.tigerairtw.com/zh-tw/'
response = requests.get(get_url, cookies=get_chrome_cookies(DOMAIN_NAME))
print(response.text)



import urllib.request

DOMAIN_NAME = '.jobbole.com'
get_url = r'https://www.tigerairtw.com/zh-tw/'
headers = {'Cookie': ['='.join((i, j)) for i, j in get_chrome_cookies(DOMAIN_NAME).items()][0]}
request = urllib.request.Request(get_url, headers=headers)
response = urllib.request.urlopen(request)
print(response.read().decode())
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-3-25d63aa18468> in <module>
#       3 DOMAIN_NAME = '.tigerairtw.com'
#       4 get_url = r'https://www.tigerairtw.com/zh-tw/'
# ----> 5 response = requests.get(get_url, cookies=get_chrome_cookies(DOMAIN_NAME))
#       6 print(response.text)
#       7
#
# <ipython-input-1-a30b579b20b4> in get_chrome_cookies(url)
#      13     conn = sqlite3.connect(".\python-chrome-cookies")
#      14     ret_dict = {}
# ---> 15     for row in conn.execute("SELECT host_key, name, path, value, encrypted_value FROM cookies"):
#      16         # if row[0] not in url:
#      17         if row[0] != url:
#
# OperationalError: no such table: cookies

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from bs4 import BeautifulSoup

    
driver = webdriver.Chrome()
URL ="https://www.tigerairtw.com/zh-tw/"
driver.get(URL)
driver.implicitly_wait(3)
#print(driver.get_cookies())

# %%
driver.find_element_by_id("dp1548725222883").click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-16-c80ad7d44ccc> in <module>
# ----> 1 driver.find_element_by_id("dp1548725222883").click()
#
# c:\python\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_id(self, id_)
#     328             driver.find_element_by_id('foo')
#     329         """
# --> 330         return self.find_element(by=By.ID, value=id_)
#     331
#     332     def find_elements_by_id(self, id_):
#
# c:\python\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     830         return self.execute(Command.FIND_ELEMENT, {
#     831             'using': by,
# --> 832             'value': value})['value']
#     833
#     834     def find_elements(self, by=By.ID, value=None):
#
# c:\python\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     295         response = self.command_executor.execute(driver_command, params)
#     296         if response:
# --> 297             self.error_handler.check_response(response)
#     298             response['value'] = self._unwrap_value(
#     299                 response.get('value', None))
#
# c:\python\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     192         elif exception_class == UnexpectedAlertPresentException and 'alert' in value:
#     193             raise exception_class(message, screen, stacktrace, value['alert'].get('text'))
# --> 194         raise exception_class(message, screen, stacktrace)
#     195
#     196     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"id","selector":"dp1548725222883"}
#   (Session info: chrome=71.0.3578.98)
#   (Driver info: chromedriver=2.44.609538 (b655c5a60b0b544917107a59d4153d4bf78e1b90),platform=Windows NT 6.1.7601 SP1 x86)

# %%
       
#driver.get("https://www.tigerairtw.com/zh-tw/")
driver.find_element_by_xpath(u"(.//*[normalize-space(text()) and normalize-space(.)='出發'])[1]/preceding::i[3]").click()
driver.find_element_by_id("select2-selectOrigin-container").click()
driver.find_element_by_id("select2-selectDestination-container").click()
driver.find_element_by_id("dp1548725222883").click()
driver.find_element_by_id("dp1548725222883").click()
driver.find_element_by_link_text(u"下月>").click()
driver.find_element_by_link_text(u"下月>").click()
driver.find_element_by_link_text(u"下月>").click()
driver.find_element_by_link_text("5").click()
driver.find_element_by_xpath("(.//*[normalize-space(text()) and normalize-space(.)='+'])[3]/following::button[1]").click()
# Out:
# ---------------------------------------------------------------------------
# ElementNotVisibleException                Traceback (most recent call last)
# <ipython-input-7-aaf59add6a2f> in <module>
#      20
#      21 #driver.get("https://www.tigerairtw.com/zh-tw/")
# ---> 22 driver.find_element_by_xpath(u"(.//*[normalize-space(text()) and normalize-space(.)='出發'])[1]/preceding::i[3]").click()
#      23 driver.find_element_by_id("select2-selectOrigin-container").click()
#      24 driver.find_element_by_id("select2-selectDestination-container").click()
#
# c:\python\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      76     def click(self):
#      77         """Clicks the element."""
# ---> 78         self._execute(Command.CLICK_ELEMENT)
#      79
#      80     def submit(self):
#
# c:\python\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     497             params = {}
#     498         params['id'] = self._id
# --> 499         return self._parent.execute(command, params)
#     500
#     501     def find_element(self, by=By.ID, value=None):
#
# c:\python\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     295         response = self.command_executor.execute(driver_command, params)
#     296         if response:
# --> 297             self.error_handler.check_response(response)
#     298             response['value'] = self._unwrap_value(
#     299                 response.get('value', None))
#
# c:\python\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     192         elif exception_class == UnexpectedAlertPresentException and 'alert' in value:
#     193             raise exception_class(message, screen, stacktrace, value['alert'].get('text'))
# --> 194         raise exception_class(message, screen, stacktrace)
#     195
#     196     def _value_or_default(self, obj, key, default):
#
# ElementNotVisibleException: Message: element not interactable
#   (Session info: chrome=71.0.3578.98)
#   (Driver info: chromedriver=2.44.609538 (b655c5a60b0b544917107a59d4153d4bf78e1b90),platform=Windows NT 6.1.7601 SP1 x86)

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from bs4 import BeautifulSoup
import re
import requests


session = requests.Session()

index_url = 'https://www.ctrip.com.hk/flights/taipei-to-okinawa/tickets-tpe-oka/?flighttype=s&dcity=tpe&acity=oka&startdate=2018-06-28&class=y&quantity=1&searchboxarg=t'

index_content = session.post(index_url,verify=False)

header = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.181 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
    'content-type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'origin': 'https://www.ctrip.com.hk',
    'referer': index_url
}

flight_api_url = 'https://www.ctrip.com.hk/flights/Ajax/SearchFlight'

param = {'context':'{"SearchNo":"1","FlightWay":"OW","SubChannel":"0","SearchToken":"1","Class":"Y","SegmentParameterList":[{"DCityCode":"TPE","ACityCode":"OKA","DDateString":"2018-06-28"}],"TravelerParameteList":[{"TravelerType":"ADT","TravelerCount":"1"},{"TravelerType":"CHD","TravelerCount":"0"},{"TravelerType":"INF","TravelerCount":"0"}]}'}

SearchResult = session.post(flight_api_url,verify=False,headers=header,data=param).json()
# Out:
# c:\python\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\python\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\python\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\python\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-2-54a4f38571fb> in <module>
#      25 param = {'context':'{"SearchNo":"1","FlightWay":"OW","SubChannel":"0","SearchToken":"1","Class":"Y","SegmentParameterList":[{"DCityCode":"TPE","ACityCode":"OKA","DDateString":"2018-06-28"}],"TravelerParameteList":[{"TravelerType":"ADT","TravelerCount":"1"},{"TravelerType":"CHD","TravelerCount":"0"},{"TravelerType":"INF","TravelerCount":"0"}]}'}
#      26
# ---> 27 SearchResult = session.post(flight_api_url,verify=False,headers=header,data=param).json()
#
# c:\python\lib\site-packages\requests\models.py in json(self, **kwargs)
#     892                     # used.
#     893                     pass
# --> 894         return complexjson.loads(self.text, **kwargs)
#     895
#     896     @property
#
# c:\python\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# c:\python\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# c:\python\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from bs4 import BeautifulSoup


WIDTH = 640
HEIGHT = 640
PIXEL_RATIO = 3.0
#UA = 'Mozilla/5.0 (Linux; Android 4.1.1; GT-N7100 Build/JRO03C) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/35.0.1916.138 Mobile Safari/537.36 T7/6.3'

UA = 'Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2272.96 Mobile Safari/537.36'


mobileEmulation = {"deviceMetrics": {"width": WIDTH, "height": HEIGHT, "pixelRatio": PIXEL_RATIO}, "userAgent": UA}
options = webdriver.ChromeOptions()
options.add_experimental_option('mobileEmulation', mobileEmulation)
#options.add_argument(r'user-data-dir=C:\Users\kidde\AppData\Local\Google\Chrome\User Data')
#options.add_argument('--proxy-server=http://proxy.seed.net.tw:8080')


#https://booking.tigerairtw.com/?lang=zh-TW



executable_path='C:\Python\Scripts\chromedriver.exe'
browser = webdriver.Chrome(executable_path, chrome_options=options)

browser.implicitly_wait(3) 
browser.get('https://hk.trip.com/flights/taipei-to-shanghai/tickets-tpe-sha/?flighttype=s&dcity=tpe&acity=sha&startdate=2019-06-06&class=y&quantity=1&searchboxarg=t')
time.sleep(10)
#印出來看看有幾筆資料吧 
#看你是要用re或是beautifulsoup來parse~
print (browser.page_source)
# Out:
# <!DOCTYPE html><html xmlns="http://www.w3.org/1999/xhtml" lang="zh-HK"><head><title>taipei到shanghai機票比價及預訂, taipei去shanghai特價機票 - Trip.com 手機版網頁</title><meta name="description" content="Trip.com 手機版提供taipei到shanghai機票比價、飛機航班查詢及預訂服務。用手機登陸 Trip.com 手機版網頁, 可隨時隨地訂taipei去shanghai優惠、特價機票。" /><meta name="keywords" content="taipei到shanghai、taipei去shanghai、taipei到 shanghai機票、taipei去shanghai機票、taipei到shanghai飛機、taipei shanghai 機票、taipei到shanghai機票預訂，Trip.com 手機版網頁" /><meta name="format-detection" content="telephone=no" /><meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1,minimal-ui" /><meta charset="utf-8" /><meta http-equiv="Content-type" content="text/html; charset=utf-8" /><meta name="apple-touch-fullscreen" content="yes" /><meta name="apple-mobile-web-app-capable" content="yes" /><link rel="canonical" href="https://hk.trip.com/flights/taipei-to-shanghai/tickets-tpe-sha/" /><link rel="alternate" hreflang="en-US" href="https://www.trip.com/flights/taipei-to-shanghai/tickets-tpe-sha/" title="English (United States)" /><link rel="alternate" hreflang="en-GB" href="https://uk.trip.com/flights/taipei-to-shanghai/tickets-tpe-sha/" title="English (United Kingdom)" /><link rel="alternate" hreflang="zh-HK" href="https://hk.trip.com/flights/taipei-to-shanghai/tickets-tpe-sha/" title="繁體中文 (香港)" /><link rel="alternate" hreflang="en-HK" href="https://hk.trip.com/flights/taipei-to-shanghai/tickets-tpe-sha/" title="English (Hong Kong)" /><link rel="alternate" hreflang="ja-JP" href="https://jp.trip.com/flights/taipei-to-shanghai/tickets-tpe-sha/" title="日本語" /><link rel="alternate" hreflang="ko-KR" href="https://kr.trip.com/flights/taipei-to-shanghai/tickets-tpe-sha/" title="한국어" /><link rel="alternate" hreflang="en-SG" href="https://sg.trip.com/flights/taipei-to-shanghai/tickets-tpe-sha/" title="English (Singapore)" /><link rel="alternate" hreflang="en-AU" href="https://au.trip.com/flights/taipei-to-shanghai/tickets-tpe-sha/" title="English (Australia)" /><link rel="alternate" hreflang="fr-FR" href="https://fr.trip.com/flights/taipei-to-shanghai/tickets-tpe-sha/" title="Français" /><link rel="alternate" hreflang="de-DE" href="https://de.trip.com/flights/taipei-to-shanghai/tickets-tpe-sha/" title="Deutsch" /><link rel="alternate" hreflang="es-ES" href="https://es.trip.com/flights/taipei-to-shanghai/tickets-tpe-sha/" title="Español" /><link rel="alternate" hreflang="ru-RU" href="https://ru.trip.com/flights/taipei-to-shanghai/tickets-tpe-sha/" title="Русский" /><link rel="alternate" hreflang="id-ID" href="https://id.trip.com/flights/taipei-to-shanghai/tickets-tpe-sha/" title="Bahasa Indonesia" /><link rel="alternate" hreflang="th-TH" href="https://th.trip.com/flights/taipei-to-shanghai/tickets-tpe-sha/" title="ภาษาไทย" /><link rel="alternate" hreflang="en-MY" href="https://my.trip.com/flights/taipei-to-shanghai/tickets-tpe-sha/" title="English (Malaysia)" /><link rel="alternate" hreflang="tl-PH" href="https://ph.trip.com/flights/taipei-to-shanghai/tickets-tpe-sha/" title="菲利宾" /><link rel="alternate" hreflang="zh-TW" href="https://tw.trip.com/flights/taipei-to-shanghai/tickets-tpe-sha/" title="繁體中文 (台湾)" /><link rel="alternate" hreflang="it-IT" href="https://it.trip.com/flights/taipei-to-shanghai/tickets-tpe-sha/" title="Italiano" /><link rel="alternate" hreflang="vi-VN" href="https://vn.trip.com/flights/taipei-to-shanghai/tickets-tpe-sha/" title="Tiếng Việt" /><link rel="alternate" hreflang="pl-PL" href="https://pl.trip.com/flights/taipei-to-shanghai/tickets-tpe-sha/" title="Polski" /><link rel="alternate" hreflang="tr-TR" href="https://tr.trip.com/flights/taipei-to-shanghai/tickets-tpe-sha/" title="Türkçe" /><link rel="alternate" hreflang="pt-BR" href="https://br.trip.com/flights/taipei-to-shanghai/tickets-tpe-sha/" title="Português (BR)" /><link rel="alternate" hreflang="el-GR" href="https://gr.trip.com/flights/taipei-to-shanghai/tickets-tpe-sha/" title="Ελληνικά" /><link rel="alternate" hreflang="nl-NL" href="https ...
# <iframe src="javascript:void(0)" title="" style="width: 0px; height: 0px; border: 0px; display: none;"></iframe><script async="true" type="text/javascript" src="https://sslwidget.criteo.com/event?a=45732&amp;v=4.5.1&amp;p0=e%3Dce%26m%3D%255B%255D&amp;p1=e%3Dexd%26site_type%3Dm&amp;p2=e%3Dvp%26p%3Dtpe-sha&amp;p3=e%3Dvs%26din%3D2019-06-06%26dout%3D%26extra_nbra%3D%26extra_nbrc%3D%26extra_nbrr%3D&amp;p4=e%3Ddis%26a%3D%255B45732%252C45732%255D&amp;adce=1" data-owner="criteo-tag"></script><script async="true" type="text/javascript" src="https://sslwidget.criteo.com/event?a=45732&amp;v=4.5.1&amp;p0=e%3Dce%26m%3D%255B%255D&amp;p1=e%3Dexd%26site_type%3Dm&amp;p2=e%3Dvp%26p%3Dtpe-sha&amp;p3=e%3Dvs%26din%3D2019-06-06%26dout%3D%26extra_nbra%3D%26extra_nbrc%3D%26extra_nbrr%3D&amp;p4=e%3Ddis&amp;adce=1" data-owner="criteo-tag"></script><script type="text/javascript" async="" src="//www.googleadservices.com/pagead/conversion_async.js"></script><script type="text/javascript" async="" src="//www.googleadservices.com/pagead/conversion_async.js"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-W5446B"></script><script async="" src="https://www.google-analytics.com/analytics.js"></script><script type="text/javascript" src="https://webresource.english.c-ctrip.com/resaresenglish/risk/ubtrms/latest/default/mrms.js?=20190211"></script><script type="text/javascript" charset="utf-8" async="" src="//webresource.english.c-ctrip.com/code/ubt/_mubt.min.js?v=20191_11.js"></script><script>!function(){function o(n,i){if(n&amp;&amp;i)for(var r in i)i.hasOwnProperty(r)&amp;&amp;(void 0===n[r]?n[r]=i[r]:n[r].constructor===Object&amp;&amp;i[r].constructor===Object?o(n[r],i[r]):n[r]=i[r])}try{var n=decodeURIComponent("");if(n.length&gt;0&amp;&amp;window.JSON&amp;&amp;"function"==typeof window.JSON.parse){var i=JSON.parse(n);void 0!==window.BOOMR_config?o(window.BOOMR_config,i):window.BOOMR_config=i}}catch(r){window.console&amp;&amp;"function"==typeof window.console.error&amp;&amp;console.error("mPulse: Could not parse configuration",r)}}();</script>
# <script>!function(e){function a(a){if(a&amp;&amp;a.data&amp;&amp;a.data.boomr_mq)e.BOOMR_mq=e.BOOMR_mq||[],e.BOOMR_mq.push(a.data.boomr_mq)}var t="https://s.go-mpulse.net/boomerang/";if("False"=="True")e.BOOMR_config=e.BOOMR_config||{},e.BOOMR_config.PageParams=e.BOOMR_config.PageParams||{},e.BOOMR_config.PageParams.pci=!0,t="https://s2.go-mpulse.net/boomerang/";if(function(){function a(a){e.BOOMR_onload=a&amp;&amp;a.timeStamp||(new Date).getTime()}if(!e.BOOMR||!e.BOOMR.version&amp;&amp;!e.BOOMR.snippetExecuted){e.BOOMR=e.BOOMR||{},e.BOOMR.snippetExecuted=!0;var n,i,r,o=document.createElement("iframe");if(e.addEventListener)e.addEventListener("load",a,!1);else if(e.attachEvent)e.attachEvent("onload",a);o.src="javascript:void(0)",o.title="",o.role="presentation",(o.frameElement||o).style.cssText="width:0;height:0;border:0;display:none;",r=document.getElementsByTagName("script")[0],r.parentNode.insertBefore(o,r);try{i=o.contentWindow.document}catch(O){n=document.domain,o.src="javascript:var d=document.open();d.domain='"+n+"';void(0);",i=o.contentWindow.document}i.open()._l=function(){var e=this.createElement("script");if(n)this.domain=n;e.id="boomr-if-as",e.src=t+"QQE64-6R65F-RH4DT-3ADQR-EJSMD",BOOMR_lstart=(new Date).getTime(),this.body.appendChild(e)},i.write("&lt;bo"+'dy onload="document._l();"&gt;'),i.close()}}(),"".length&gt;0)if(e&amp;&amp;"performance"in e&amp;&amp;e.performance&amp;&amp;"function"==typeof e.performance.setResourceTimingBufferSize)e.performance.setResourceTimingBufferSize();if(e.addEventListener)e.addEventListener("message",a);var n=e.navigator;if(n&amp;&amp;"serviceWorker"in n&amp;&amp;n.serviceWorker.addEventListener)n.serviceWorker.addEventListener("message",a);!function(){if(BOOMR=e.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var a=""=="true"?1:0,t="",n="2mlyhrixgvbukxday4ea-f-92aa01460-clientnsv4-s.akamaihd.net",i={"ak.v":19,"ak.cp":"642325","ak.ai":parseInt("420247",10),"ak.ol":"0","ak.cr":36,"ak.ipv":4,"ak.proto":"h2","ak.rid":"82939ad","ak.r":19803,"ak.a2":a,"ak.m":"a","ak.n":"essl","ak.bpcip":"211.23.131.0","ak.cport":34799,"ak.gh":"61.220.62.140","ak.quicv":"","ak.tlsv":"tls1.2","ak.0rtt":"","ak.csrc":"-","ak.acc":""};if(""!==t)i["ak.ruds"]=t;var r={i:!1,av:function(a){var t="http.initiator";if(a&amp;&amp;(!a[t]||"spa_hard"===a[t]))i["ak.feo"]=void 0!==e.aFeoApplied?1:0,BOOMR.addVar(i)},rv:function(){var e=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.r","ak.acc"];BOOMR.removeVar(e)}};BOOMR.plugins.AK={akVars:i,akDNSPreFetchDomain:n,init:function(){if(!r.i){var e=BOOMR.subscribe;e("before_beacon",r.av,null,null),e("onbeacon",r.rv,null,null),r.i=!0}return this},is_complete:function(){return!0}}}}()}(window);</script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="//webresource.english.c-ctrip.com/resaresenglish/ibu/flighth5/ibuCtripConfig.1029f5cb.js" src="//webresource.english.c-ctrip.com/resaresenglish/ibu/flighth5/ibuCtripConfig.1029f5cb.js"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="//webresource.english.c-ctrip.com/resaresenglish/ibu/flighth5/controllers2/pages/flights/first.a582ca3e.js" crossorigin="anonymous" src="//webresource.english.c-ctrip.com/resaresenglish/ibu/flighth5/controllers2/pages/flights/first.a582ca3e.js"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="captcha" crossorigin="anonymous" src="//webresource.english.c-ctrip.com/resaresenglish/infosec/captcha/js/captcha.min.31f3a8c0.js"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="accounts" crossorigin="anonymous" src="//webresource.english.c-ctrip.com/resaresenglish/basebiz/i18nh5accountssdk/components/accounts.6b05b797.js"></script><script type="text/javascript" charset="utf-8" async="" data-req ...
# <script type="text/javascript">window.criteo_q=window.criteo_q||[];window.criteo_q.push({event:"setAccount",account:google_tag_manager["GTM-W5446B"].macro(29)},{event:"setHashedEmail",email:""},{event:"setSiteType",type:"m"},{event:"viewItem",item:"tpe-sha"},{event:"viewSearch",checkin_date:google_tag_manager["GTM-W5446B"].macro(30),checkout_date:google_tag_manager["GTM-W5446B"].macro(31),extra_nbra:"",extra_nbrc:"",extra_nbrr:""});</script></div><div style="display: none; visibility: hidden;"><script type="text/javascript" src="https://pages.trip.com/js/market/ld.js" async="true"></script>
# <script type="text/javascript">window.criteo_q=window.criteo_q||[];window.criteo_q.push({event:"setAccount",account:"45732"},{event:"setHashedEmail",email:""},{event:"setSiteType",type:"m"},{event:"viewItem",item:"tpe-sha"},{event:"viewSearch",checkin_date:google_tag_manager["GTM-W5446B"].macro(32),checkout_date:google_tag_manager["GTM-W5446B"].macro(33),extra_nbra:"",extra_nbrc:"",extra_nbrr:""});</script></div><div id="criteo-tags-div" style="display: none;"><iframe height="0" width="0" src="//dis.as.criteo.com/dis/dis.aspx?p=45732&amp;cb=96133899796&amp;ref=&amp;sc_r=640x640&amp;sc_d=24&amp;site_type=m" title="Criteo DIS iframe" style="display: none;"></iframe><iframe height="0" width="0" src="//dis.as.criteo.com/dis/dis.aspx?p=45732&amp;cb=89982477592&amp;ref=&amp;sc_r=640x640&amp;sc_d=24&amp;site_type=m" title="Criteo DIS iframe" style="display: none;"></iframe></div></body></html>

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from bs4 import BeautifulSoup


WIDTH = 640
HEIGHT = 640
PIXEL_RATIO = 3.0
#UA = 'Mozilla/5.0 (Linux; Android 4.1.1; GT-N7100 Build/JRO03C) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/35.0.1916.138 Mobile Safari/537.36 T7/6.3'

UA = 'Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2272.96 Mobile Safari/537.36'


mobileEmulation = {"deviceMetrics": {"width": WIDTH, "height": HEIGHT, "pixelRatio": PIXEL_RATIO}, "userAgent": UA}
options = webdriver.ChromeOptions()
options.add_experimental_option('mobileEmulation', mobileEmulation)
#options.add_argument(r'user-data-dir=C:\Users\kidde\AppData\Local\Google\Chrome\User Data')
#options.add_argument('--proxy-server=http://proxy.seed.net.tw:8080')


#https://booking.tigerairtw.com/?lang=zh-TW



executable_path='C:\Python\Scripts\chromedriver.exe'
browser = webdriver.Chrome(executable_path, chrome_options=options)

browser.implicitly_wait(3) 
browser.get('https://hk.trip.com/flights/taipei-to-shanghai/tickets-tpe-spk/?flighttype=s&dcity=tpe&acity=spk&startdate=2019-03-05&class=y&quantity=1&searchboxarg=t')
time.sleep(10)
#印出來看看有幾筆資料吧 
#看你是要用re或是beautifulsoup來parse~
print (browser.page_source)
# Out:
# <!DOCTYPE html><html xmlns="http://www.w3.org/1999/xhtml" lang="zh-HK"><head><title>taipei到shanghai機票比價及預訂, taipei去shanghai特價機票 - Trip.com 手機版網頁</title><meta name="description" content="Trip.com 手機版提供taipei到shanghai機票比價、飛機航班查詢及預訂服務。用手機登陸 Trip.com 手機版網頁, 可隨時隨地訂taipei去shanghai優惠、特價機票。" /><meta name="keywords" content="taipei到shanghai、taipei去shanghai、taipei到 shanghai機票、taipei去shanghai機票、taipei到shanghai飛機、taipei shanghai 機票、taipei到shanghai機票預訂，Trip.com 手機版網頁" /><meta name="format-detection" content="telephone=no" /><meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1,minimal-ui" /><meta charset="utf-8" /><meta http-equiv="Content-type" content="text/html; charset=utf-8" /><meta name="apple-touch-fullscreen" content="yes" /><meta name="apple-mobile-web-app-capable" content="yes" /><link rel="canonical" href="https://hk.trip.com/flights/taipei-to-shanghai/tickets-tpe-spk/" /><link rel="alternate" hreflang="en-US" href="https://www.trip.com/flights/taipei-to-shanghai/tickets-tpe-spk/" title="English (United States)" /><link rel="alternate" hreflang="en-GB" href="https://uk.trip.com/flights/taipei-to-shanghai/tickets-tpe-spk/" title="English (United Kingdom)" /><link rel="alternate" hreflang="zh-HK" href="https://hk.trip.com/flights/taipei-to-shanghai/tickets-tpe-spk/" title="繁體中文 (香港)" /><link rel="alternate" hreflang="en-HK" href="https://hk.trip.com/flights/taipei-to-shanghai/tickets-tpe-spk/" title="English (Hong Kong)" /><link rel="alternate" hreflang="ja-JP" href="https://jp.trip.com/flights/taipei-to-shanghai/tickets-tpe-spk/" title="日本語" /><link rel="alternate" hreflang="ko-KR" href="https://kr.trip.com/flights/taipei-to-shanghai/tickets-tpe-spk/" title="한국어" /><link rel="alternate" hreflang="en-SG" href="https://sg.trip.com/flights/taipei-to-shanghai/tickets-tpe-spk/" title="English (Singapore)" /><link rel="alternate" hreflang="en-AU" href="https://au.trip.com/flights/taipei-to-shanghai/tickets-tpe-spk/" title="English (Australia)" /><link rel="alternate" hreflang="fr-FR" href="https://fr.trip.com/flights/taipei-to-shanghai/tickets-tpe-spk/" title="Français" /><link rel="alternate" hreflang="de-DE" href="https://de.trip.com/flights/taipei-to-shanghai/tickets-tpe-spk/" title="Deutsch" /><link rel="alternate" hreflang="es-ES" href="https://es.trip.com/flights/taipei-to-shanghai/tickets-tpe-spk/" title="Español" /><link rel="alternate" hreflang="ru-RU" href="https://ru.trip.com/flights/taipei-to-shanghai/tickets-tpe-spk/" title="Русский" /><link rel="alternate" hreflang="id-ID" href="https://id.trip.com/flights/taipei-to-shanghai/tickets-tpe-spk/" title="Bahasa Indonesia" /><link rel="alternate" hreflang="th-TH" href="https://th.trip.com/flights/taipei-to-shanghai/tickets-tpe-spk/" title="ภาษาไทย" /><link rel="alternate" hreflang="en-MY" href="https://my.trip.com/flights/taipei-to-shanghai/tickets-tpe-spk/" title="English (Malaysia)" /><link rel="alternate" hreflang="tl-PH" href="https://ph.trip.com/flights/taipei-to-shanghai/tickets-tpe-spk/" title="菲利宾" /><link rel="alternate" hreflang="zh-TW" href="https://tw.trip.com/flights/taipei-to-shanghai/tickets-tpe-spk/" title="繁體中文 (台湾)" /><link rel="alternate" hreflang="it-IT" href="https://it.trip.com/flights/taipei-to-shanghai/tickets-tpe-spk/" title="Italiano" /><link rel="alternate" hreflang="vi-VN" href="https://vn.trip.com/flights/taipei-to-shanghai/tickets-tpe-spk/" title="Tiếng Việt" /><link rel="alternate" hreflang="pl-PL" href="https://pl.trip.com/flights/taipei-to-shanghai/tickets-tpe-spk/" title="Polski" /><link rel="alternate" hreflang="tr-TR" href="https://tr.trip.com/flights/taipei-to-shanghai/tickets-tpe-spk/" title="Türkçe" /><link rel="alternate" hreflang="pt-BR" href="https://br.trip.com/flights/taipei-to-shanghai/tickets-tpe-spk/" title="Português (BR)" /><link rel="alternate" hreflang="el-GR" href="https://gr.trip.com/flights/taipei-to-shanghai/tickets-tpe-spk/" title="Ελληνικά" /><link rel="alternate" hreflang="nl-NL" href="https ...
# <iframe src="javascript:void(0)" title="" style="width: 0px; height: 0px; border: 0px; display: none;"></iframe><script async="true" type="text/javascript" src="https://sslwidget.criteo.com/event?a=45732&amp;v=4.5.1&amp;p0=e%3Dce%26m%3D%255B%255D&amp;p1=e%3Dexd%26site_type%3Dm&amp;p2=e%3Dvp%26p%3Dtpe-spk&amp;p3=e%3Dvs%26din%3D2019-03-05%26dout%3D%26extra_nbra%3D%26extra_nbrc%3D%26extra_nbrr%3D&amp;p4=e%3Ddis%26a%3D%255B45732%252C45732%255D&amp;adce=1" data-owner="criteo-tag"></script><script async="true" type="text/javascript" src="https://sslwidget.criteo.com/event?a=45732&amp;v=4.5.1&amp;p0=e%3Dce%26m%3D%255B%255D&amp;p1=e%3Dexd%26site_type%3Dm&amp;p2=e%3Dvp%26p%3Dtpe-spk&amp;p3=e%3Dvs%26din%3D2019-03-05%26dout%3D%26extra_nbra%3D%26extra_nbrc%3D%26extra_nbrr%3D&amp;p4=e%3Ddis&amp;adce=1" data-owner="criteo-tag"></script><script type="text/javascript" async="" src="//www.googleadservices.com/pagead/conversion_async.js"></script><script type="text/javascript" async="" src="//www.googleadservices.com/pagead/conversion_async.js"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-W5446B"></script><script async="" src="https://www.google-analytics.com/analytics.js"></script><script type="text/javascript" src="https://webresource.english.c-ctrip.com/resaresenglish/risk/ubtrms/latest/default/mrms.js?=20190211"></script><script type="text/javascript" charset="utf-8" async="" src="//webresource.english.c-ctrip.com/code/ubt/_mubt.min.js?v=20191_11.js"></script><script>!function(){function o(n,i){if(n&amp;&amp;i)for(var r in i)i.hasOwnProperty(r)&amp;&amp;(void 0===n[r]?n[r]=i[r]:n[r].constructor===Object&amp;&amp;i[r].constructor===Object?o(n[r],i[r]):n[r]=i[r])}try{var n=decodeURIComponent("");if(n.length&gt;0&amp;&amp;window.JSON&amp;&amp;"function"==typeof window.JSON.parse){var i=JSON.parse(n);void 0!==window.BOOMR_config?o(window.BOOMR_config,i):window.BOOMR_config=i}}catch(r){window.console&amp;&amp;"function"==typeof window.console.error&amp;&amp;console.error("mPulse: Could not parse configuration",r)}}();</script>
# <script>!function(e){function a(a){if(a&amp;&amp;a.data&amp;&amp;a.data.boomr_mq)e.BOOMR_mq=e.BOOMR_mq||[],e.BOOMR_mq.push(a.data.boomr_mq)}var t="https://s.go-mpulse.net/boomerang/";if("False"=="True")e.BOOMR_config=e.BOOMR_config||{},e.BOOMR_config.PageParams=e.BOOMR_config.PageParams||{},e.BOOMR_config.PageParams.pci=!0,t="https://s2.go-mpulse.net/boomerang/";if(function(){function a(a){e.BOOMR_onload=a&amp;&amp;a.timeStamp||(new Date).getTime()}if(!e.BOOMR||!e.BOOMR.version&amp;&amp;!e.BOOMR.snippetExecuted){e.BOOMR=e.BOOMR||{},e.BOOMR.snippetExecuted=!0;var n,i,r,o=document.createElement("iframe");if(e.addEventListener)e.addEventListener("load",a,!1);else if(e.attachEvent)e.attachEvent("onload",a);o.src="javascript:void(0)",o.title="",o.role="presentation",(o.frameElement||o).style.cssText="width:0;height:0;border:0;display:none;",r=document.getElementsByTagName("script")[0],r.parentNode.insertBefore(o,r);try{i=o.contentWindow.document}catch(O){n=document.domain,o.src="javascript:var d=document.open();d.domain='"+n+"';void(0);",i=o.contentWindow.document}i.open()._l=function(){var e=this.createElement("script");if(n)this.domain=n;e.id="boomr-if-as",e.src=t+"QQE64-6R65F-RH4DT-3ADQR-EJSMD",BOOMR_lstart=(new Date).getTime(),this.body.appendChild(e)},i.write("&lt;bo"+'dy onload="document._l();"&gt;'),i.close()}}(),"".length&gt;0)if(e&amp;&amp;"performance"in e&amp;&amp;e.performance&amp;&amp;"function"==typeof e.performance.setResourceTimingBufferSize)e.performance.setResourceTimingBufferSize();if(e.addEventListener)e.addEventListener("message",a);var n=e.navigator;if(n&amp;&amp;"serviceWorker"in n&amp;&amp;n.serviceWorker.addEventListener)n.serviceWorker.addEventListener("message",a);!function(){if(BOOMR=e.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var a="false"=="true"?1:0,t="",n="2mlyhrliopsmcxdazhea-f-7da92cf32-clientnsv4-s.akamaihd.net",i={"ak.v":19,"ak.cp":"642325","ak.ai":parseInt("420247",10),"ak.ol":"0","ak.cr":24,"ak.ipv":4,"ak.proto":"h2","ak.rid":"a13edde","ak.r":26702,"ak.a2":a,"ak.m":"a","ak.n":"essl","ak.bpcip":"211.23.131.0","ak.cport":11750,"ak.gh":"210.61.249.68","ak.quicv":"","ak.tlsv":"tls1.2","ak.0rtt":"","ak.csrc":"-","ak.acc":""};if(""!==t)i["ak.ruds"]=t;var r={i:!1,av:function(a){var t="http.initiator";if(a&amp;&amp;(!a[t]||"spa_hard"===a[t]))i["ak.feo"]=void 0!==e.aFeoApplied?1:0,BOOMR.addVar(i)},rv:function(){var e=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.r","ak.acc"];BOOMR.removeVar(e)}};BOOMR.plugins.AK={akVars:i,akDNSPreFetchDomain:n,init:function(){if(!r.i){var e=BOOMR.subscribe;e("before_beacon",r.av,null,null),e("onbeacon",r.rv,null,null),r.i=!0}return this},is_complete:function(){return!0}}}}()}(window);</script>
#                     <script async="" src="https://ds-aksb-a.akamaihd.net/aksb.min.js"></script><script>var w=window;if(w.performance||w.mozPerformance||w.msPerformance||w.webkitPerformance){var d=document;AKSB=w.AKSB||{},AKSB.q=AKSB.q||[],AKSB.mark=AKSB.mark||function(e,_){AKSB.q.push(["mark",e,_||(new Date).getTime()])},AKSB.measure=AKSB.measure||function(e,_,t){AKSB.q.push(["measure",e,_,t||(new Date).getTime()])},AKSB.done=AKSB.done||function(e){AKSB.q.push(["done",e])},AKSB.mark("firstbyte",(new Date).getTime()),AKSB.prof={custid:"642325",ustr:"",originlat:"0",clientrtt:"24",ghostip:"210.61.249.68",ipv6:false,pct:"10",clientip:"211.23.131.197",requestid:"a13edde",region:"26702",protocol:"h2",blver:14,akM:"a",akN:"ae",akTT:"O",akTX:"1",akTI:"a13edde",ai:"420247",ra:"false",pmgn:"",pmgi:"",pmp:"",qc:""},function(e){var _=d.createElement("script");_.async="async",_.src=e;var t=d.getElementsByTagName("script"),t=t[t.length-1];t.parentNode.insertBefore(_,t)}(("https:"===d.location.protocol?"https:":"http:")+"//ds-aksb-a.akamaihd.net/aksb.min.js")}</script>
#                     <script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="//webresource.english.c-ctrip.com/resaresenglish/ibu/flighth5/ibuCtripConfig.1029f5cb.js" src="//webresource.english.c-ctrip.com/resaresenglish/ibu/flighth5/ibuCtripConfig.1029f5cb.js"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="//webresource.english.c-ctrip.com/resaresenglish/ibu/flighth5/controllers2/pages/flights/first.a582ca3e.js" crossorigin="anonymous" src="//webresource.english.c-ctrip.com/resaresenglish/ibu/flighth5/controllers2/pages/flights/first.a582ca3e.js"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="captcha" crossorigin="anonymous" src="//webresource.english.c-ctrip.com/resaresenglish/infosec/captcha/js/captcha.min.31f3a8c0.js"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="accounts" crossorigin="anonymous" src="//webresource.english.c-ctrip.com/resaresenglish/basebiz/i18nh5accountssdk/components/accounts.6b05b797.js"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="i18n" crossorigin="anonymous" src="/m/i18n/100067662-330151-6002-100015471/zh-HK.js?v=2018-11-19"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="commonComponents" crossorigin="anonymous" src="//webresource.english.c-ctrip.com/resaresenglish/ibu/h5common/components/common_components_flights.86f80a47.js"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="l10n" crossorigin="anonymous" src="//webresource.english.c-ctrip.com/resaresenglish/ibu/h5common/components/l10n.73e7460d.js"></script><link rel="stylesheet" href="//webresource.english.c-ctrip.com/res/concat?f=/resaresenglish/ibu/flighth5/resource/css/animate.min.afe1dd8d.css,/resaresenglish/ibu/h5common/components/menu.4581f1c4.css,accounts.acd059e7.css" /><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="analytics" crossorigin="anonymous" src="//webresource.english.c-ctrip.com/resaresenglish/ibu/flighth5/common/analytics.8dc583f2.js"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="tracker" crossorigin="anonymous" src="//webresource.english.c-ctrip.com/resaresenglish/ibu/tracker/tracker_next.799cd795.js"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="_" data-requiremodule="GaGtm" crossorigin="anonymous" src="//webresource.english.c-ctrip.com/resaresenglish/ibu/onlinecommon/assets/ibu_gagtag_online_bundle.14717101.js"></script><script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/827436400/?random=1549846984654&amp;cv=9&amp;fst=1549846984654&amp;num=1&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=640&amp;u_w=640&amp;u_ah=640&amp;u_aw=640&amp;u_cd=24&amp;u_his=2&amp;u_tz=480&amp;u_java=false&amp;u_nplug=0&amp;u_nmime=0&amp;gtm=2wg1r0&amp;sendb=1&amp;data=flight_enddate%3D%3Bflight_startdate%3D2019-03-05%3Bflight_destid%3Dspk%3Bflight_originid%3Dtpe%3Bflight_pagetype%3Dintl%20flight%20list%20page&amp;frm=0&amp;url=https%3A%2F%2Fhk.trip.com%2Fm%2Fflights%2Ftaipei-to-shanghai%2Ftickets-tpe-spk%2F%3Ftriptype%3D0%26dcitycode%3Dtpe%26acitycode%3Dspk%26ddate%3D2019-03-05%26classtype%3D0%26adult%3D1%26searchboxarg%3Dt%26dcity%3Dtaipei%26acity%3Dshanghai&amp;tiba=taipei%E5%88%B0shanghai%E6%A9%9F%E7%A5%A8%E6%AF%94%E5%83%B9%E5%8F%8A%E9%A0%90%E8%A8%82%2C%20taipei%E5%8E%BBshanghai%E7%89%B9%E5%83%B9%E6%A9%9F%E7%A5%A8%20-%20Trip.com%20%E6%89%8B%E6%A9%9F%E7%89%88%E7%B6%B2%E9%A0%81&amp;async=1&amp;rfmt=3&amp;fmt=4"></script><script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/827357333/?random=1549846984667&amp;cv=9&amp;fst=1549846984667&amp;n ...
# <script type="text/javascript">window.criteo_q=window.criteo_q||[];window.criteo_q.push({event:"setAccount",account:google_tag_manager["GTM-W5446B"].macro(29)},{event:"setHashedEmail",email:""},{event:"setSiteType",type:"m"},{event:"viewItem",item:"tpe-spk"},{event:"viewSearch",checkin_date:google_tag_manager["GTM-W5446B"].macro(30),checkout_date:google_tag_manager["GTM-W5446B"].macro(31),extra_nbra:"",extra_nbrc:"",extra_nbrr:""});</script></div><div style="display: none; visibility: hidden;"><script type="text/javascript" src="https://pages.trip.com/js/market/ld.js" async="true"></script>
# <script type="text/javascript">window.criteo_q=window.criteo_q||[];window.criteo_q.push({event:"setAccount",account:"45732"},{event:"setHashedEmail",email:""},{event:"setSiteType",type:"m"},{event:"viewItem",item:"tpe-spk"},{event:"viewSearch",checkin_date:google_tag_manager["GTM-W5446B"].macro(32),checkout_date:google_tag_manager["GTM-W5446B"].macro(33),extra_nbra:"",extra_nbrc:"",extra_nbrr:""});</script></div><div id="criteo-tags-div" style="display: none;"><iframe height="0" width="0" src="//dis.as.criteo.com/dis/dis.aspx?p=45732&amp;cb=91927080312&amp;ref=&amp;sc_r=640x640&amp;sc_d=24&amp;site_type=m" title="Criteo DIS iframe" style="display: none;"></iframe><iframe height="0" width="0" src="//dis.as.criteo.com/dis/dis.aspx?p=45732&amp;cb=75169558074&amp;ref=&amp;sc_r=640x640&amp;sc_d=24&amp;site_type=m" title="Criteo DIS iframe" style="display: none;"></iframe></div></body></html>
